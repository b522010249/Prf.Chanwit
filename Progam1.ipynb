# %%
FullName = "Krit Rpj"
StudentID = 68424500
Gpax = 3.25
Age = 25

if type(FullName) == str:
    print("is String", FullName)
else:
    print("is not String", FullName)
if type(StudentID) == complex:
    print("is complex", StudentID)
else:
    print("is not complex", StudentID)
if type(Gpax) == float:
    print("is float", Gpax)
else:
    print("is not float", Gpax)
if type(Age) == int:
    print("is Integer", Age)
else:
    print("is not Integer", Age)
