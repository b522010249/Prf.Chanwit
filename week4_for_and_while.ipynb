# %%
running = 10 
for i in range (running):
    print("Round is :",i)
# Out:
# Round is : 0
# Round is : 1
# Round is : 2
# Round is : 3
# Round is : 4
# Round is : 5
# Round is : 6
# Round is : 7
# Round is : 8
# Round is : 9

# %%
check = True

while(check):
    print("check")
    check = False
# Out:
# check

# %%
running_str = input("จำนวนรอบที่ต้องการวิ่ง : ")
running_int = int(running_str)

for i in range(running_int):
    print("Round is :",i+1)
# Out:
# Round is : 1
# Round is : 2
# Round is : 3
# Round is : 4
# Round is : 5
# Round is : 6
# Round is : 7
# Round is : 8
# Round is : 9
# Round is : 10

# %%
state = input("สั่งให้เริ่มวิ่ง ด้วยตำสั่ง 1")

if(state == '1'):
    state_running = True
else:
    satte_running = False
i = 1
while(state):
    print("Round : ", i)
    i = i +1
    interup = input("ต้องการหยุดหรือไม่ 1 หยุด หรือ 0 ไม่หยุด")
    if(interup == '1'):
        state = True
    elif(interup == '0'):
        state = False

# %%
Q = "Press Q = Exit"
M = "Press M = Main"
S = "Press S = Start In Program"
state = True
while(state):
    print(Q)
    print(M)
    print(S)
    
    inp = input("Menu Selected : ")
    if(inp == 'Q'):
        state = False
    elif(inp == 'M'):
        print("Home Manu")
    elif(inp == 'S'):
        round = input("จำนวนรอบที่ต้องการ : ")
        round_int = int(round)
        for i in range(round_int):
                print("Round is :",i+1)
        else:
            print("Home Manu")
# Out:
# Press Q = Exit
# Press M = Main
# Press S = Start In Program
# Round is : 1
# Round is : 2
# Round is : 3
# Round is : 4
# Round is : 5
# Round is : 6
# Round is : 7
# Round is : 8
# Round is : 9
# Round is : 10
# Home Manu
# Press Q = Exit
# Press M = Main
# Press S = Start In Program
